# %%
# !git clone https://github.com/vuducanh0802/unet-improvement.git
# Out:
# Cloning into 'unet-improvement'...
# remote: Enumerating objects: 10342, done.
# remote: Counting objects: 100% (146/146), done.
# remote: Compressing objects: 100% (96/96), done.
# remote: Total 10342 (delta 55), reused 121 (delta 47), pack-reused 10196
# Receiving objects: 100% (10342/10342), 448.60 MiB | 23.56 MiB/s, done.
# Resolving deltas: 100% (55/55), done.
# Checking out files: 100% (10272/10272), done.

# %%
# !unzip /content/drive/MyDrive/DATA/jig-vision-segmentation.zip -d /content

# %%
# %cd /content/unet-improvement/semantic_segmentation_unet/
# Out:
# /content/unet-improvement/semantic_segmentation_unet

# %%
# !pip install albumentations==0.4.6
import albumentations 
from albumentations.pytorch import ToTensorV2

# %%
# !rm -rf /content/lens_dataset_1/masks/.ipynb_checkpoints
# !rm -rf /content/lens_dataset_2/masks/.ipynb_checkpoints
# !rm -rf /content/lens_dataset_1/rois/.ipynb_checkpoints
# !rm -rf /content/lens_dataset_2/rois/.ipynb_checkpoints

# %%
# !python3 train.py
# Out:
# Got 290676/3268608 with acc 8.89
# Dice score: 1.7634005546569824
# 100% 50/50 [00:08<00:00,  5.89it/s, loss=-41.1]
# => Saving checkpoint
# Got 2620168/3268608 with acc 80.16
# Dice score: 1.7766976356506348
# 100% 50/50 [00:08<00:00,  5.83it/s, loss=-41]
# => Saving checkpoint
# Got 2356636/3268608 with acc 72.10
# Dice score: 1.8967899084091187
# 100% 50/50 [00:08<00:00,  5.85it/s, loss=-41.9]
# => Saving checkpoint
# Got 2145554/3268608 with acc 65.64
# Dice score: 1.8878365755081177
# 100% 50/50 [00:08<00:00,  5.80it/s, loss=-47.1]
# => Saving checkpoint
# Got 2457342/3268608 with acc 75.18
# Dice score: 1.91056227684021
# 100% 50/50 [00:08<00:00,  5.84it/s, loss=-57.6]
# => Saving checkpoint
# Got 2154673/3268608 with acc 65.92
# Dice score: 1.8869590759277344
# 100% 50/50 [00:08<00:00,  5.82it/s, loss=-58.1]
# => Saving checkpoint
# Got 2255171/3268608 with acc 68.99
# Dice score: 1.8939608335494995
# 100% 50/50 [00:08<00:00,  5.81it/s, loss=-74.3]
# => Saving checkpoint
# ...
